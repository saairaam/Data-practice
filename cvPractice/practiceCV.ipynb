# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('waterbody.png')

# %%
img
# Out:
# array([[[ 95, 105, 111],
#         [ 89,  99, 105],
#         [ 84,  93,  99],
#         ...,
#         [ 49,  43,  31],
#         [ 49,  43,  31],
#         [ 49,  43,  31]],
#
#        [[ 91, 100, 107],
#         [ 83,  93,  99],
#         [ 76,  85,  92],
#         ...,
#         [ 49,  43,  31],
#         [ 49,  43,  31],
#         [ 49,  43,  31]],
#
#        [[ 86,  96, 103],
#         [ 77,  87,  94],
#         [ 68,  77,  84],
#         ...,
#         [ 49,  43,  31],
#         [ 49,  43,  31],
#         [ 49,  43,  31]],
#
#        ...,
#
#        [[217, 199, 147],
#         [217, 199, 147],
#         [217, 199, 147],
#         ...,
#         [144, 144, 145],
#         [143, 143, 144],
#         [142, 142, 143]],
#
#        [[216, 198, 146],
#         [216, 198, 146],
#         [216, 198, 146],
#         ...,
#         [113, 113, 117],
#         [119, 120, 126],
#         [116, 118, 123]],
#
#        [[215, 197, 146],
#         [215, 197, 146],
#         [215, 197, 146],
# ...

# %%
img.shape
# Out:
# (1250, 2506, 3)

# %%
plt.imshow(img)

# %%
newimg =cv2.cvtColor(img,cv2.COLOR_BGR2RGB)

# %%
plt.imshow(newimg)

# %%
grayimage = cv2.imread('waterbody.png',cv2.IMREAD_GRAYSCALE)

# %%
plt.imshow(grayimage,cmap='binary')
