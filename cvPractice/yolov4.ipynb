# %%
pip install pytubefix
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 85.1/85.1 kB 2.4 MB/s eta 0:00:00
# ...
#   WARNING: The script pytubefix is installed in '/Library/Frameworks/Python.framework/Versions/3.11/bin' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# ...
#
# [notice] A new release of pip is available: 24.0 -> 24.2
# [notice] To update, run: python3.11 -m pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
from ultralytics import YOLO

# Load a pre-trained YOLOv10n model
model = YOLO("yolo11x.pt") 

results = model.track(source="https://www.youtube.com/watch?v=MNn9qKG2UFI", conf=0.3, iou=0.5, show=True)
# Out:
# 1/1: https://www.youtube.com/watch?v=MNn9qKG2UFI... Success ✅ (9184 frames of shape 1920x1080 at 30.00 FPS)
#
#
# WARNING ⚠️ inference results will accumulate in RAM unless `stream=True` is passed, causing potential out-of-memory
# errors for large sources or long-running streams and videos. See https://docs.ultralytics.com/modes/predict/ for help.
#
# Example:
#     results = model(source=..., stream=True)  # generator of Results objects
#     for r in results:
#         boxes = r.boxes  # Boxes object for bbox outputs
#         masks = r.masks  # Masks object for segment masks outputs
#         probs = r.probs  # Class probabilities for classification outputs
#
# 0: 384x640 8 cars, 1550.5ms
# 0: 384x640 3 cars, 1 truck, 1275.7ms
# 0: 384x640 3 cars, 1133.4ms
# 0: 384x640 3 cars, 1461.5ms
# 0: 384x640 1 car, 1178.1ms
# 0: 384x640 2 cars, 1228.1ms
# 0: 384x640 2 cars, 1236.7ms
# 0: 384x640 4 cars, 1166.0ms
# 0: 384x640 3 cars, 1 truck, 1396.5ms
# 0: 384x640 2 cars, 1 truck, 1234.6ms
# ...
