# %%
import cv2
img1 = cv2.imread('../assest/waterbodies/waterbody.png')
img2 = cv2.imread('../assest/waterbodies/waterbody2.png')

# %%
import matplotlib.pyplot as plt

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
img1.shape
# Out:
# (1250, 2506, 3)

# %%
img2.shape
# Out:
# (1200, 2588, 3)

# %%
#resize

# %%
img1= cv2.resize(img1,(2500,1250))
img2= cv2.resize(img2,(2500,1250))

# %%
plt.imshow(img1)

# %%
plt.imshow(img2)

# %%
bImage = cv2.addWeighted(src1=img1,alpha=0.1,src2=img2,beta=0.5,gamma=0.5)
plt.imshow(bImage)

# %%
#overlay
img1 = cv2.imread('../assest/waterbodies/waterbody.png')
img2 = cv2.imread('../assest/waterbodies/waterbody2.png')

# %%
img2= cv2.resize(img2,(1250,1250))

# %%
plt.imshow(img2)

# %%
large_img = img1
small_img = img2
x_offset =0
y_offset= 0
x_end =x_offset+small_img.shape[1]
y_end= y_offset+small_img.shape[0]

large_img[y_offset:y_end,x_offset:x_end]= small_img

# %%
plt.imshow(large_img)

# %%
img1 = cv2.imread('../assest/waterbodies/waterbody.png')
img2 = cv2.imread('../assest/waterbodies/waterbody2.png')
